# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as transforms
from vitpol import ViT
import time
import matplotlib.pyplot as plt
import numpy as np


def main():
    model = ViT(
        img_size=224,
        patch_size=16,
        num_classes=10,
        in_channels=3,
        dim=512,
        depth=8,
        heads=8,
        mlp_dim=1024,
        dropout=0.1
    )

    batch_size = 64

    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])

    transform_train = transforms.Compose([
        transforms.RandomResizedCrop(224, scale=(0.7, 1.0)),
        transforms.RandomHorizontalFlip(),
        transforms.ColorJitter(0.2, 0.2, 0.2, 0.1),
        transforms.RandAugment(num_ops=2, magnitude=7),
        transforms.ToTensor(),
        normalize,
        transforms.RandomErasing(p=0.25)
    ])

    transform_test = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        normalize
    ])

    train_dataset = torchvision.datasets.Imagenette(
        root='../data',
        split='train',
        size='320px',
        download=False,
        transform=transform_train
    )

    test_dataset = torchvision.datasets.Imagenette(
        root='../data',
        split='val',
        size='320px',
        download=False,
        transform=transform_test
    )

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,
                              num_workers=4, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False,
                             num_workers=4, pin_memory=True)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)

    optimizer = optim.AdamW(model.parameters(), lr=1e-4, weight_decay=0.03)
    criterion = nn.CrossEntropyLoss(label_smoothing=0.1)

    scheduler = optim.lr_scheduler.CosineAnnealingWarmRestarts(
        optimizer,
        T_0=10,
        T_mult=2
    )

    def train_epoch(model, loader, optimizer, criterion, device):
        model.train()
        total_loss, correct, total = 0, 0, 0

        for imgs, labels in loader:
            imgs, labels = imgs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(imgs)
            loss = criterion(outputs, labels)
            loss.backward()

            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()

            total_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

        return total_loss / len(loader), correct / total

    def test_epoch(model, loader, criterion, device):
        model.eval()
        total_loss, correct, total = 0, 0, 0

        with torch.no_grad():
            for imgs, labels in loader:
                imgs, labels = imgs.to(device), labels.to(device)
                outputs = model(imgs)
                loss = criterion(outputs, labels)

                total_loss += loss.item()
                _, predicted = outputs.max(1)
                total += labels.size(0)
                correct += predicted.eq(labels).sum().item()

        return total_loss / len(loader), correct / total

    epochs = 50

    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []
    epoch_times = []

    best_test_loss = float('inf')
    best_epoch = 0

    patience = 7
    epochs_no_improve = 0

    log_file = open("training_log.txt", "w", encoding="utf-8")

    print(f"Starting training on {device}...")

    for epoch in range(epochs):
        start_time = time.time()

        train_loss, train_acc = train_epoch(model, train_loader, optimizer, criterion, device)
        test_loss, test_acc = test_epoch(model, test_loader, criterion, device)
        scheduler.step()

        train_losses.append(train_loss)
        val_losses.append(test_loss)
        train_accs.append(train_acc)
        val_accs.append(test_acc)

        epoch_duration = time.time() - start_time
        epoch_times.append(epoch_duration)

        log_str = (f"Epoch {epoch+1}/{epochs} | "
                   f"Time: {epoch_duration:.2f}s | "
                   f"Train Acc: {train_acc:.4f}, Val Acc: {test_acc:.4f} | "
                   f"Train Loss: {train_loss:.4f}, Val Loss: {test_loss:.4f}\n")

        print(log_str, end="")
        log_file.write(log_str)
        log_file.flush()

        if test_loss < best_test_loss:
            best_test_loss = test_loss
            best_epoch = epoch + 1
            epochs_no_improve = 0
            torch.save(model.state_dict(), 'best_vit_model.pth')
            print(f"---> New best model saved! Loss: {test_loss:.4f}")
        else:
            epochs_no_improve += 1
            print(f"No improvement: {epochs_no_improve}/{patience}")

        if epochs_no_improve >= patience:
            print(f"\nEarly stopping at epoch {epoch+1}")
            break

        if (epoch + 1) % 10 == 0:
            torch.save(model.state_dict(), f'vit_epoch_{epoch+1}.pth')

    avg_time = sum(epoch_times) / len(epoch_times)
    total_time = sum(epoch_times)

    summary_str = (f"\n{'='*35}\n"
                   f"Training Complete!\n"
                   f"Total Time: {total_time:.2f}s ({total_time/60:.2f} min)\n"
                   f"Average Time per Epoch: {avg_time:.2f}s\n"
                   f"Best Validation Accuracy: {max(val_accs):.4f}\n"
                   f"Best Epoch: {best_epoch}\n"
                   f"{'='*35}")

    print(summary_str)
    log_file.write(summary_str + "\n")

    plt.style.use('default')
    epochs_range = np.arange(1, len(train_losses)+1)

    plt.figure(figsize=(9,6))
    plt.plot(epochs_range, train_losses, linewidth=2, label='Train Loss')
    plt.plot(epochs_range, val_losses, linewidth=2, label='Validation Loss')
    plt.axvline(best_epoch, linestyle='--', linewidth=1.5, label=f'Best Epoch = {best_epoch}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig('research_loss_curve.png', dpi=300)
    plt.show()

    plt.figure(figsize=(9,6))
    plt.plot(epochs_range, train_accs, linewidth=2, label='Train Accuracy')
    plt.plot(epochs_range, val_accs, linewidth=2, label='Validation Accuracy')
    plt.axvline(best_epoch, linestyle='--', linewidth=1.5, label=f'Best Epoch = {best_epoch}')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig('research_accuracy_curve.png', dpi=300)
    plt.show()

    plt.figure(figsize=(9,6))
    plt.plot(epochs_range, epoch_times, linewidth=2, label='Epoch Time (sec)')
    plt.xlabel('Epoch')
    plt.ylabel('Seconds')
    plt.title('Training Time per Epoch')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig('research_time_curve.png', dpi=300)
    plt.show()

    log_file.close()


if __name__ == '__main__':
    main()
# Out:
# ViT(
#   (patch_embed): PatchEmbedding(
#     (proj): Conv2d(1, 128, kernel_size=(7, 7), stride=(7, 7))
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (transformer): Sequential(
#     (0): TransformerBlock(
#       (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (to_qkv): Linear(in_features=128, out_features=384, bias=False)
#         (proj): Linear(in_features=128, out_features=128, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=128, out_features=512, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=512, out_features=128, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (1): TransformerBlock(
#       (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (to_qkv): Linear(in_features=128, out_features=384, bias=False)
#         (proj): Linear(in_features=128, out_features=128, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=128, out_features=512, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=512, out_features=128, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (2): TransformerBlock(
#       (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (to_qkv): Linear(in_features=128, out_features=384, bias=False)
#         (proj): Linear(in_features=128, out_features=128, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=128, out_features=512, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=512, out_features=128, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (3): TransformerBlock(
#       (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (to_qkv): Linear(in_features=128, out_features=384, bias=False)
#         (proj): Linear(in_features=128, out_features=128, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=128, out_features=512, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=512, out_features=128, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (head): Linear(in_features=128, out_features=10, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# Starting training on cuda...
# Epoch 1/50 | Time: 62.89s | Train Acc: 0.2125, Val Acc: 0.3271 | Train Loss: 2.2052, Val Loss: 2.0392
# ---> New best model saved! Loss: 2.0392
# Epoch 2/50 | Time: 68.66s | Train Acc: 0.3402, Val Acc: 0.4578 | Train Loss: 1.9703, Val Loss: 1.7293
# ---> New best model saved! Loss: 1.7293
# Epoch 3/50 | Time: 71.20s | Train Acc: 0.3995, Val Acc: 0.4978 | Train Loss: 1.8582, Val Loss: 1.6690
# ---> New best model saved! Loss: 1.6690
# Epoch 4/50 | Time: 73.43s | Train Acc: 0.4439, Val Acc: 0.5136 | Train Loss: 1.7635, Val Loss: 1.6161
# ---> New best model saved! Loss: 1.6161
# Epoch 5/50 | Time: 75.25s | Train Acc: 0.4772, Val Acc: 0.5794 | Train Loss: 1.7013, Val Loss: 1.4859
# ---> New best model saved! Loss: 1.4859
# Epoch 6/50 | Time: 77.09s | Train Acc: 0.5165, Val Acc: 0.5896 | Train Loss: 1.6277, Val Loss: 1.4755
# ---> New best model saved! Loss: 1.4755
# Epoch 7/50 | Time: 77.56s | Train Acc: 0.5404, Val Acc: 0.6206 | Train Loss: 1.5802, Val Loss: 1.4052
# ---> New best model saved! Loss: 1.4052
# Epoch 8/50 | Time: 77.30s | Train Acc: 0.5557, Val Acc: 0.6372 | Train Loss: 1.5434, Val Loss: 1.3710
# ---> New best model saved! Loss: 1.3710
# Epoch 9/50 | Time: 77.34s | Train Acc: 0.5703, Val Acc: 0.6433 | Train Loss: 1.5136, Val Loss: 1.3542
# ---> New best model saved! Loss: 1.3542
# Epoch 10/50 | Time: 79.15s | Train Acc: 0.5786, Val Acc: 0.6466 | Train Loss: 1.4931, Val Loss: 1.3484
# ---> New best model saved! Loss: 1.3484
# Epoch 11/50 | Time: 78.10s | Train Acc: 0.5275, Val Acc: 0.6130 | Train Loss: 1.5974, Val Loss: 1.3987
# No improvement: 1/7
# Epoch 12/50 | Time: 78.00s | Train Acc: 0.5475, Val Acc: 0.5972 | Train Loss: 1.5556, Val Loss: 1.4696
# No improvement: 2/7
# Epoch 13/50 | Time: 78.20s | Train Acc: 0.5573, Val Acc: 0.6089 | Train Loss: 1.5305, Val Loss: 1.4497
# No improvement: 5/7
# Epoch 33/50 | Time: 77.90s | Train Acc: 0.6597, Val Acc: 0.6973 | Train Loss: 1.3138, Val Loss: 1.2328
# No improvement: 6/7
# Epoch 34/50 | Time: 78.95s | Train Acc: 0.6562, Val Acc: 0.7266 | Train Loss: 1.3062, Val Loss: 1.1616
# No improvement: 7/7
#
# Early stopping at epoch 34
#
# ===================================
# Training Complete!
# Total Time: 2626.13s (43.77 min)
# Average Time per Epoch: 77.24s
# Best Validation Accuracy: 0.7383
# Best Epoch: 27
# ===================================

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as transforms
from vitpol import ViT
import time
import matplotlib.pyplot as plt
import numpy as np
import torch.nn.functional as F


def main():

    model = ViT(
        img_size=224,
        patch_size=16,
        num_classes=10,
        in_channels=3,
        dim=512,
        depth=8,
        heads=8,
        mlp_dim=1024,
        dropout=0.1
    )

    batch_size = 64

    normalize = transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )

    transform_train = transforms.Compose([
        transforms.RandomResizedCrop(224, scale=(0.7, 1.0)),
        transforms.RandomHorizontalFlip(),
        transforms.ColorJitter(0.2, 0.2, 0.2, 0.1),
        transforms.RandAugment(num_ops=2, magnitude=7),
        transforms.ToTensor(),
        normalize,
        transforms.RandomErasing(p=0.25)
    ])

    transform_test = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        normalize
    ])

    train_dataset = torchvision.datasets.Imagenette(
        root='../data',
        split='train',
        size='320px',
        download=False,
        transform=transform_train
    )

    test_dataset = torchvision.datasets.Imagenette(
        root='../data',
        split='val',
        size='320px',
        download=False,
        transform=transform_test
    )

    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=4,
        pin_memory=True
    )

    test_loader = DataLoader(
        test_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4,
        pin_memory=True
    )

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    model = model.to(device)

    optimizer = optim.AdamW(
        model.parameters(),
        lr=1e-4,
        weight_decay=0.03
    )

    criterion = nn.CrossEntropyLoss(
        label_smoothing=0.1
    )

    scheduler = optim.lr_scheduler.CosineAnnealingWarmRestarts(
        optimizer,
        T_0=10,
        T_mult=2
    )

    def train_epoch(model, loader, optimizer, criterion, device):

        model.train()

        total_loss = 0
        correct = 0
        total = 0

        for imgs, labels in loader:

            imgs = imgs.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()

            outputs = model(imgs)

            loss = criterion(outputs, labels)

            loss.backward()

            torch.nn.utils.clip_grad_norm_(
                model.parameters(),
                1.0
            )

            optimizer.step()

            total_loss += loss.item()

            _, predicted = outputs.max(1)

            total += labels.size(0)

            correct += predicted.eq(labels).sum().item()

        return total_loss / len(loader), correct / total

    def test_epoch(model, loader, criterion, device):

        model.eval()

        total_loss = 0
        correct = 0
        total = 0

        with torch.no_grad():

            for imgs, labels in loader:

                imgs = imgs.to(device)
                labels = labels.to(device)

                outputs = model(imgs)

                loss = criterion(outputs, labels)

                total_loss += loss.item()

                _, predicted = outputs.max(1)

                total += labels.size(0)

                correct += predicted.eq(labels).sum().item()

        return total_loss / len(loader), correct / total

    epochs = 50

    train_losses = []
    val_losses = []

    train_accs = []
    val_accs = []

    epoch_times = []

    # история изменения p
    p_history = []

    best_test_loss = float('inf')
    best_epoch = 0

    patience = 7
    epochs_no_improve = 0

    log_file = open(
        "training_log.txt",
        "w",
        encoding="utf-8"
    )

    print(f"Starting training on {device}...")

    for epoch in range(epochs):

        start_time = time.time()

        train_loss, train_acc = train_epoch(
            model,
            train_loader,
            optimizer,
            criterion,
            device
        )

        test_loss, test_acc = test_epoch(
            model,
            test_loader,
            criterion,
            device
        )

        scheduler.step()

        # ==========================================
        # Сохраняем значения p
        # ==========================================

        current_p = []

        for block in model.transformer:

            p = 1.0 + F.softplus(block.attn.p_raw)

            current_p.append(
                p.detach().cpu().numpy()
            )

        p_history.append(current_p)

        # ==========================================

        train_losses.append(train_loss)
        val_losses.append(test_loss)

        train_accs.append(train_acc)
        val_accs.append(test_acc)

        epoch_duration = time.time() - start_time

        epoch_times.append(epoch_duration)

        log_str = (
            f"Epoch {epoch+1}/{epochs} | "
            f"Time: {epoch_duration:.2f}s | "
            f"Train Acc: {train_acc:.4f}, "
            f"Val Acc: {test_acc:.4f} | "
            f"Train Loss: {train_loss:.4f}, "
            f"Val Loss: {test_loss:.4f}\n"
        )

        print(log_str, end="")

        log_file.write(log_str)
        log_file.flush()

        if test_loss < best_test_loss:

            best_test_loss = test_loss
            best_epoch = epoch + 1

            epochs_no_improve = 0

            torch.save(
                model.state_dict(),
                'best_vit_model.pth'
            )

            print(
                f"---> New best model saved! "
                f"Loss: {test_loss:.4f}"
            )

        else:

            epochs_no_improve += 1

            print(
                f"No improvement: "
                f"{epochs_no_improve}/{patience}"
            )

        if epochs_no_improve >= patience:

            print(
                f"\nEarly stopping at epoch "
                f"{epoch+1}"
            )

            break

        if (epoch + 1) % 10 == 0:

            torch.save(
                model.state_dict(),
                f'vit_epoch_{epoch+1}.pth'
            )

    avg_time = sum(epoch_times) / len(epoch_times)
    total_time = sum(epoch_times)

    summary_str = (
        f"\n{'='*35}\n"
        f"Training Complete!\n"
        f"Total Time: {total_time:.2f}s "
        f"({total_time/60:.2f} min)\n"
        f"Average Time per Epoch: "
        f"{avg_time:.2f}s\n"
        f"Best Validation Accuracy: "
        f"{max(val_accs):.4f}\n"
        f"Best Epoch: {best_epoch}\n"
        f"{'='*35}"
    )

    print(summary_str)

    log_file.write(summary_str + "\n")

    plt.style.use('default')

    epochs_range = np.arange(
        1,
        len(train_losses) + 1
    )

    # ==========================================
    # Loss
    # ==========================================

    plt.figure(figsize=(9, 6))

    plt.plot(
        epochs_range,
        train_losses,
        linewidth=2,
        label='Train Loss'
    )

    plt.plot(
        epochs_range,
        val_losses,
        linewidth=2,
        label='Validation Loss'
    )

    plt.axvline(
        best_epoch,
        linestyle='--',
        linewidth=1.5,
        label=f'Best Epoch = {best_epoch}'
    )

    plt.xlabel('Epoch')
    plt.ylabel('Loss')

    plt.title(
        'Training and Validation Loss'
    )

    plt.legend()

    plt.grid(True, alpha=0.3)

    plt.tight_layout()

    plt.savefig(
        'research_loss_curve.png',
        dpi=300
    )

    plt.show()

    # ==========================================
    # Accuracy
    # ==========================================

    plt.figure(figsize=(9, 6))

    plt.plot(
        epochs_range,
        train_accs,
        linewidth=2,
        label='Train Accuracy'
    )

    plt.plot(
        epochs_range,
        val_accs,
        linewidth=2,
        label='Validation Accuracy'
    )

    plt.axvline(
        best_epoch,
        linestyle='--',
        linewidth=1.5,
        label=f'Best Epoch = {best_epoch}'
    )

    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')

    plt.title(
        'Training and Validation Accuracy'
    )

    plt.legend()

    plt.grid(True, alpha=0.3)

    plt.tight_layout()

    plt.savefig(
        'research_accuracy_curve.png',
        dpi=300
    )

    plt.show()

    # ==========================================
    # Time
    # ==========================================

    plt.figure(figsize=(9, 6))

    plt.plot(
        epochs_range,
        epoch_times,
        linewidth=2,
        label='Epoch Time (sec)'
    )

    plt.xlabel('Epoch')
    plt.ylabel('Seconds')

    plt.title('Training Time per Epoch')

    plt.legend()

    plt.grid(True, alpha=0.3)

    plt.tight_layout()

    plt.savefig(
        'research_time_curve.png',
        dpi=300
    )

    plt.show()

    # ==========================================
    # Анализ параметра p
    # ==========================================

    p_history = np.array(p_history)

    # shape = [epochs, layers, heads]

    num_layers = p_history.shape[1]
    num_heads = p_history.shape[2]

    # Графики изменения p

    for layer_idx in range(num_layers):

        plt.figure(figsize=(10, 6))

        for head_idx in range(num_heads):

            plt.plot(
                epochs_range,
                p_history[:, layer_idx, head_idx],
                linewidth=2,
                label=f'Head {head_idx}'
            )

        plt.xlabel('Epoch')
        plt.ylabel('p value')

        plt.title(
            f'Evolution of p '
            f'(Layer {layer_idx})'
        )

        plt.legend()

        plt.grid(True, alpha=0.3)

        plt.tight_layout()

        plt.savefig(
            f'p_evolution_layer_{layer_idx}.png',
            dpi=300
        )

        plt.show()

    # ==========================================
    # Финальные значения p
    # ==========================================

    final_p = p_history[-1]

    print("\nFinal p values:\n")

    log_file.write("\nFinal p values:\n")

    for layer_idx, layer_p in enumerate(final_p):

        layer_str = f"Layer {layer_idx}:\n"

        print(layer_str, end="")
        log_file.write(layer_str)

        for head_idx, p_val in enumerate(layer_p):

            head_str = (
                f"  Head {head_idx}: "
                f"{p_val:.4f}\n"
            )

            print(head_str, end="")
            log_file.write(head_str)

    log_file.close()


if __name__ == '__main__':
    main()
# Out:
# ViT(
#   (patch_embed): PatchEmbedding(
#     (proj): Conv2d(1, 128, kernel_size=(7, 7), stride=(7, 7))
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (transformer): Sequential(
#     (0): TransformerBlock(
#       (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (to_qkv): Linear(in_features=128, out_features=384, bias=False)
#         (proj): Linear(in_features=128, out_features=128, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=128, out_features=512, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=512, out_features=128, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (1): TransformerBlock(
#       (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (to_qkv): Linear(in_features=128, out_features=384, bias=False)
#         (proj): Linear(in_features=128, out_features=128, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=128, out_features=512, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=512, out_features=128, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (2): TransformerBlock(
#       (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (to_qkv): Linear(in_features=128, out_features=384, bias=False)
#         (proj): Linear(in_features=128, out_features=128, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=128, out_features=512, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=512, out_features=128, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (3): TransformerBlock(
#       (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (to_qkv): Linear(in_features=128, out_features=384, bias=False)
#         (proj): Linear(in_features=128, out_features=128, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=128, out_features=512, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=512, out_features=128, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#   (head): Linear(in_features=128, out_features=10, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# Starting training on cuda...
# Epoch 1/50 | Time: 63.59s | Train Acc: 0.2059, Val Acc: 0.2978 | Train Loss: 2.2161, Val Loss: 2.0213
# ---> New best model saved! Loss: 2.0213
# Epoch 2/50 | Time: 69.49s | Train Acc: 0.3218, Val Acc: 0.4525 | Train Loss: 2.0082, Val Loss: 1.7694
# ---> New best model saved! Loss: 1.7694
# Epoch 3/50 | Time: 73.79s | Train Acc: 0.3899, Val Acc: 0.4833 | Train Loss: 1.8690, Val Loss: 1.6679
# ---> New best model saved! Loss: 1.6679
# Epoch 4/50 | Time: 75.70s | Train Acc: 0.4456, Val Acc: 0.5429 | Train Loss: 1.7700, Val Loss: 1.5684
# ---> New best model saved! Loss: 1.5684
# Epoch 5/50 | Time: 78.04s | Train Acc: 0.4815, Val Acc: 0.5628 | Train Loss: 1.7025, Val Loss: 1.5158
# ---> New best model saved! Loss: 1.5158
# Epoch 6/50 | Time: 79.64s | Train Acc: 0.5137, Val Acc: 0.6117 | Train Loss: 1.6253, Val Loss: 1.4233
# ---> New best model saved! Loss: 1.4233
# Epoch 7/50 | Time: 79.94s | Train Acc: 0.5365, Val Acc: 0.6252 | Train Loss: 1.5775, Val Loss: 1.3993
# ---> New best model saved! Loss: 1.3993
# Epoch 8/50 | Time: 80.35s | Train Acc: 0.5596, Val Acc: 0.6352 | Train Loss: 1.5273, Val Loss: 1.3707
# ---> New best model saved! Loss: 1.3707
# Epoch 9/50 | Time: 78.13s | Train Acc: 0.5669, Val Acc: 0.6438 | Train Loss: 1.5061, Val Loss: 1.3587
# ---> New best model saved! Loss: 1.3587
# Epoch 10/50 | Time: 79.09s | Train Acc: 0.5714, Val Acc: 0.6484 | Train Loss: 1.4998, Val Loss: 1.3521
# ---> New best model saved! Loss: 1.1316
# Epoch 29/50 | Time: 81.48s | Train Acc: 0.6916, Val Acc: 0.7383 | Train Loss: 1.2159, Val Loss: 1.1322
# No improvement: 1/7
# Epoch 30/50 | Time: 81.78s | Train Acc: 0.7042, Val Acc: 0.7391 | Train Loss: 1.2035, Val Loss: 1.1345
# No improvement: 2/7
# Epoch 31/50 | Time: 82.32s | Train Acc: 0.6588, Val Acc: 0.7266 | Train Loss: 1.3035, Val Loss: 1.1642
# No improvement: 3/7
# Epoch 32/50 | Time: 83.04s | Train Acc: 0.6536, Val Acc: 0.6978 | Train Loss: 1.3138, Val Loss: 1.2233
# No improvement: 4/7
# Epoch 33/50 | Time: 82.12s | Train Acc: 0.6617, Val Acc: 0.7093 | Train Loss: 1.2962, Val Loss: 1.2092
# No improvement: 5/7
# Epoch 34/50 | Time: 83.76s | Train Acc: 0.6653, Val Acc: 0.7083 | Train Loss: 1.2831, Val Loss: 1.2076
# No improvement: 6/7
# Epoch 35/50 | Time: 81.78s | Train Acc: 0.6723, Val Acc: 0.7325 | Train Loss: 1.2714, Val Loss: 1.1496
# No improvement: 7/7
#
# Early stopping at epoch 35
#
# ===================================
# Training Complete!
# Total Time: 2753.25s (45.89 min)
# Average Time per Epoch: 78.66s
# Best Validation Accuracy: 0.7414
# Best Epoch: 28
# ===================================
# Final p values:
#
# Layer 0:
#   Head 0: 1.7203
#   Head 1: 1.7309
#   Head 2: 1.7101
#   Head 3: 1.7187
#   Head 4: 1.7253
#   Head 5: 1.7341
#   Head 6: 1.7261
#   Head 7: 1.7250
# Layer 1:
#   Head 0: 1.7178
#   Head 1: 1.7183
#   Head 2: 1.7217
#   Head 3: 1.7179
#   Head 4: 1.7267
#   Head 5: 1.7376
#   Head 6: 1.7244
#   Head 7: 1.7215
# Layer 2:
#   Head 0: 1.7109
#   Head 1: 1.7230
#   Head 2: 1.7250
#   Head 3: 1.7208
#   Head 4: 1.7117
#   Head 5: 1.7190
#   Head 6: 1.7108
#   Head 7: 1.7270
# Layer 3:
#   Head 0: 1.7160
#   Head 1: 1.7143
#   Head 2: 1.7271
#   Head 3: 1.7182
#   Head 4: 1.7227
#   Head 5: 1.7182
#   Head 6: 1.7229
#   Head 7: 1.7206
# Layer 4:
#   Head 0: 1.7138
#   Head 1: 1.7192
#   Head 2: 1.7150
#   Head 3: 1.7185
#   Head 4: 1.7144
#   Head 5: 1.7215
#   Head 6: 1.7154
#   Head 7: 1.7192
# Layer 5:
#   Head 0: 1.7186
#   Head 1: 1.7156
#   Head 2: 1.7083
#   Head 3: 1.7169
#   Head 4: 1.7175
#   Head 5: 1.7130
#   Head 6: 1.7167
#   Head 7: 1.7143
# Layer 6:
#   Head 0: 1.7095
#   Head 1: 1.7149
#   Head 2: 1.7105
#   Head 3: 1.7240
#   Head 4: 1.7059
#   Head 5: 1.7111
#   Head 6: 1.7125
#   Head 7: 1.7160
# Layer 7:
#   Head 0: 1.7130
#   Head 1: 1.7111
#   Head 2: 1.7099
#   Head 3: 1.7089
#   Head 4: 1.7073
#   Head 5: 1.7106
#   Head 6: 1.7090
#   Head 7: 1.7096
