# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as transforms
from vitpol import ViT
import time
import torch.nn.functional as F

# def print_p_values(model):
#     print("\n=== p VALUES (per head) ===")
#     for name, module in model.named_modules():
#         if hasattr(module, "p_raw"):
#             p = 1 + F.softplus(module.p_raw)
#             print(f"{name}: {p.detach().cpu().numpy()}")


def print_p_values(model):
    print("\n=== p VALUES (per head) ===")
    for name, module in model.named_modules():
        if hasattr(module, "p_raw"):
            p = module.p_raw  # ← вот это важно
            print(f"{name}: {p.detach().cpu().numpy()}")
            
def main():

    model = ViT(
        img_size=224,
        patch_size=16,
        num_classes=10,
        in_channels=3,
        dim=384,
        depth=7,
        heads=6
    )

    print(model)

    batch_size = 32

    # Нормализация ImageNet
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

    # Аугментации для train 
    transform_train = transforms.Compose([
        transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),  # ← ЗАПЯТАЯ!
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandAugment(num_ops=2, magnitude=9),
        transforms.ToTensor(),
        normalize
    ])

    # Для test/val
    transform_test = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        normalize
    ])

    train_dataset = torchvision.datasets.Imagenette(
        root='../data',
        split='train',
        size='320px',
        download=False,
        transform=transform_train
    )

    test_dataset = torchvision.datasets.Imagenette(
        root='../data',
        split='val',
        size='320px',
        download=False,
        transform=transform_test
    )

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)
    optimizer = optim.AdamW(model.parameters(), lr=3e-4, weight_decay=0.05)
    criterion = nn.CrossEntropyLoss()
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=50)

    def train_epoch(model, loader, optimizer, criterion, device):
        model.train()
        total_loss, correct, total = 0, 0, 0
        for imgs, labels in loader:
            imgs, labels = imgs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(imgs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            total_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()
        return total_loss / len(loader), correct / total

    def test_epoch(model, loader, criterion, device):
        model.eval()
        total_loss, correct, total = 0, 0, 0
        with torch.no_grad():
            for imgs, labels in loader:
                imgs, labels = imgs.to(device), labels.to(device)
                outputs = model(imgs)
                loss = criterion(outputs, labels)
                
                total_loss += loss.item()
                _, predicted = outputs.max(1)
                total += labels.size(0)
                correct += predicted.eq(labels).sum().item()
        return total_loss / len(loader), correct / total

    # Настройки цикла
    epochs = 50
    test_accs = []
    epoch_times = []  # Список для хранения времени каждой эпохи
    best_test_loss = float('inf')

    # === EARLY STOPPING ===
    patience = 7
    epochs_no_improve = 0

    log_file = open("training_log.txt", "w", encoding="utf-8")

    print(f"Starting training on {device}...")

    for epoch in range(epochs):
        start_time = time.time()  # Засекаем время начала эпохи
        
        train_loss, train_acc = train_epoch(model, train_loader, optimizer, criterion, device)
        test_loss, test_acc = test_epoch(model, test_loader, criterion, device)
        scheduler.step()
        
        end_time = time.time()  # Засекаем время окончания
        epoch_duration = end_time - start_time
        epoch_times.append(epoch_duration)
        
        test_accs.append(test_acc)

        # Подготовка строки лога
        log_str = (f"Epoch {epoch + 1}/{epochs} | "
                   f"Time: {epoch_duration:.2f}s | "
                   f"Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f} | "
                   f"Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}\n")
        
        print(log_str, end="")
        log_file.write(log_str)
        log_file.flush()

        if test_loss < best_test_loss:
            best_test_loss = test_loss
            epochs_no_improve = 0
            torch.save(model.state_dict(), 'best_vit_model.pth')
            print(f"---> New best model saved! Loss: {test_loss:.4f}")
        else:
            epochs_no_improve += 1
            print(f"No improvement: {epochs_no_improve}/{patience}")

        # === EARLY STOPPING ===
        if epochs_no_improve >= patience:
            print(f"\n⛔ Early stopping at epoch {epoch+1}")
            break

        # if (epoch + 1) % 10 == 0:
            # torch.save(model.state_dict(), f'vit_epoch_{epoch+1}.pth')

    # Итоговая статистика
    avg_time = sum(epoch_times) / len(epoch_times)
    total_time = sum(epoch_times)
    
    summary_str = (f"\n{'='*30}\n"
                   f"Training Complete!\n"
                   f"Total Time: {total_time:.2f}s ({total_time/60:.2f} min)\n"
                   f"Average Time per Epoch: {avg_time:.2f}s\n"
                   f"Best Test Accuracy: {max(test_accs):.4f}\n"
                   f"{'='*30}")
    
    print(summary_str)
    log_file.write(summary_str + "\n")
    log_file.close()
    
    print("\n🔥 FINAL p VALUES:")
    print_p_values(model)

if __name__ == "__main__":
    main()
# Out:
# ViT(
#   (patch_embed): PatchEmbedding(
#     (proj): Conv2d(3, 384, kernel_size=(16, 16), stride=(16, 16))
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (transformer): Sequential(
#     (0): TransformerBlock(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (to_qkv): Linear(in_features=384, out_features=1152, bias=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=384, out_features=512, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=512, out_features=384, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (1): TransformerBlock(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (to_qkv): Linear(in_features=384, out_features=1152, bias=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=384, out_features=512, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=512, out_features=384, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (2): TransformerBlock(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (to_qkv): Linear(in_features=384, out_features=1152, bias=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=384, out_features=512, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=512, out_features=384, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (3): TransformerBlock(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (to_qkv): Linear(in_features=384, out_features=1152, bias=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=384, out_features=512, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=512, out_features=384, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (4): TransformerBlock(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (to_qkv): Linear(in_features=384, out_features=1152, bias=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=384, out_features=512, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=512, out_features=384, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (5): TransformerBlock(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (to_qkv): Linear(in_features=384, out_features=1152, bias=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=384, out_features=512, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=512, out_features=384, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (6): TransformerBlock(
#       (norm1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (attn): Attention(
#         (to_qkv): Linear(in_features=384, out_features=1152, bias=False)
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (norm2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=384, out_features=512, bias=True)
#         (1): GELU(approximate='none')
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=512, out_features=384, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#     )
#   )
#   (norm): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#   (head): Linear(in_features=384, out_features=10, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# Starting training on cuda...
# Epoch 1/50 | Time: 41.14s | Train Acc: 0.1875, Test Acc: 0.2451 | Train Loss: 2.2162, Test Loss: 2.0692
# ---> New best model saved! Loss: 2.0692
# Epoch 2/50 | Time: 45.16s | Train Acc: 0.2564, Test Acc: 0.3090 | Train Loss: 2.0646, Test Loss: 1.9135
# ---> New best model saved! Loss: 1.9135
# Epoch 3/50 | Time: 46.91s | Train Acc: 0.3118, Test Acc: 0.3442 | Train Loss: 1.9382, Test Loss: 1.8171
# ---> New best model saved! Loss: 1.8171
# Epoch 4/50 | Time: 48.01s | Train Acc: 0.3482, Test Acc: 0.3679 | Train Loss: 1.8544, Test Loss: 1.7863
# ---> New best model saved! Loss: 1.7863
# Epoch 5/50 | Time: 48.38s | Train Acc: 0.3717, Test Acc: 0.4232 | Train Loss: 1.7920, Test Loss: 1.6625
# ---> New best model saved! Loss: 1.6625
# Epoch 6/50 | Time: 48.19s | Train Acc: 0.3848, Test Acc: 0.4245 | Train Loss: 1.7545, Test Loss: 1.6653
# No improvement: 1/7
# Epoch 7/50 | Time: 48.09s | Train Acc: 0.4094, Test Acc: 0.4668 | Train Loss: 1.7085, Test Loss: 1.5494
# ---> New best model saved! Loss: 1.5494
# Epoch 8/50 | Time: 48.09s | Train Acc: 0.4149, Test Acc: 0.5032 | Train Loss: 1.6740, Test Loss: 1.4679
# ---> New best model saved! Loss: 1.4679
# Epoch 9/50 | Time: 48.44s | Train Acc: 0.4321, Test Acc: 0.5001 | Train Loss: 1.6438, Test Loss: 1.4782
# No improvement: 1/7
# Epoch 10/50 | Time: 48.14s | Train Acc: 0.4500, Test Acc: 0.4930 | Train Loss: 1.5961, Test Loss: 1.4914
# No improvement: 2/7
# Epoch 11/50 | Time: 48.43s | Train Acc: 0.4647, Test Acc: 0.5169 | Train Loss: 1.5485, Test Loss: 1.4194
# ---> New best model saved! Loss: 1.4194
# Epoch 12/50 | Time: 48.03s | Train Acc: 0.4898, Test Acc: 0.5534 | Train Loss: 1.5000, Test Loss: 1.3366
# ---> New best model saved! Loss: 1.3366
# Epoch 13/50 | Time: 48.87s | Train Acc: 0.5036, Test Acc: 0.5766 | Train Loss: 1.4507, Test Loss: 1.2736
# ---> New best model saved! Loss: 1.2736
# Epoch 14/50 | Time: 48.12s | Train Acc: 0.5143, Test Acc: 0.5783 | Train Loss: 1.4288, Test Loss: 1.2569
# ---> New best model saved! Loss: 1.2569
# Epoch 15/50 | Time: 48.73s | Train Acc: 0.5288, Test Acc: 0.5699 | Train Loss: 1.3829, Test Loss: 1.2836
# No improvement: 1/7
# Epoch 16/50 | Time: 47.73s | Train Acc: 0.5376, Test Acc: 0.5789 | Train Loss: 1.3619, Test Loss: 1.2585
# No improvement: 2/7
# Epoch 17/50 | Time: 48.07s | Train Acc: 0.5446, Test Acc: 0.6005 | Train Loss: 1.3367, Test Loss: 1.1931
# ---> New best model saved! Loss: 1.1931
# Epoch 18/50 | Time: 48.31s | Train Acc: 0.5499, Test Acc: 0.6110 | Train Loss: 1.3094, Test Loss: 1.1679
# ---> New best model saved! Loss: 1.1679
# Epoch 19/50 | Time: 48.69s | Train Acc: 0.5644, Test Acc: 0.6354 | Train Loss: 1.2879, Test Loss: 1.1031
# ---> New best model saved! Loss: 1.1031
# Epoch 20/50 | Time: 48.27s | Train Acc: 0.5765, Test Acc: 0.6369 | Train Loss: 1.2393, Test Loss: 1.0967
# ---> New best model saved! Loss: 1.0967
# Epoch 21/50 | Time: 48.42s | Train Acc: 0.5848, Test Acc: 0.6211 | Train Loss: 1.2189, Test Loss: 1.1283
# No improvement: 1/7
# Epoch 22/50 | Time: 48.32s | Train Acc: 0.5909, Test Acc: 0.6504 | Train Loss: 1.2111, Test Loss: 1.0604
# ---> New best model saved! Loss: 1.0604
# Epoch 23/50 | Time: 48.14s | Train Acc: 0.6038, Test Acc: 0.6385 | Train Loss: 1.1654, Test Loss: 1.0968
# No improvement: 1/7
# Epoch 24/50 | Time: 48.11s | Train Acc: 0.6169, Test Acc: 0.6601 | Train Loss: 1.1381, Test Loss: 1.0562
# ---> New best model saved! Loss: 1.0562
# Epoch 25/50 | Time: 48.26s | Train Acc: 0.6235, Test Acc: 0.6487 | Train Loss: 1.1189, Test Loss: 1.0771
# No improvement: 1/7
# Epoch 26/50 | Time: 47.94s | Train Acc: 0.6335, Test Acc: 0.6708 | Train Loss: 1.0994, Test Loss: 0.9951
# ---> New best model saved! Loss: 0.9951
# Epoch 27/50 | Time: 48.36s | Train Acc: 0.6382, Test Acc: 0.6629 | Train Loss: 1.0676, Test Loss: 1.0283
# No improvement: 1/7
# Epoch 28/50 | Time: 48.27s | Train Acc: 0.6446, Test Acc: 0.6729 | Train Loss: 1.0535, Test Loss: 0.9998
# No improvement: 2/7
# Epoch 29/50 | Time: 48.10s | Train Acc: 0.6557, Test Acc: 0.7004 | Train Loss: 1.0321, Test Loss: 0.9121
# ---> New best model saved! Loss: 0.9121
# Epoch 30/50 | Time: 48.01s | Train Acc: 0.6530, Test Acc: 0.6930 | Train Loss: 1.0109, Test Loss: 0.9546
# No improvement: 1/7
# Epoch 31/50 | Time: 48.40s | Train Acc: 0.6689, Test Acc: 0.6963 | Train Loss: 0.9888, Test Loss: 0.9377
# No improvement: 2/7
# Epoch 32/50 | Time: 47.73s | Train Acc: 0.6693, Test Acc: 0.6925 | Train Loss: 0.9752, Test Loss: 0.9868
# No improvement: 3/7
# Epoch 33/50 | Time: 48.31s | Train Acc: 0.6765, Test Acc: 0.6978 | Train Loss: 0.9699, Test Loss: 0.9467
# No improvement: 4/7
# Epoch 34/50 | Time: 48.61s | Train Acc: 0.6825, Test Acc: 0.7014 | Train Loss: 0.9371, Test Loss: 0.9373
# No improvement: 5/7
# Epoch 35/50 | Time: 47.73s | Train Acc: 0.6867, Test Acc: 0.7113 | Train Loss: 0.9247, Test Loss: 0.9081
# ---> New best model saved! Loss: 0.9081
# Epoch 36/50 | Time: 47.82s | Train Acc: 0.6938, Test Acc: 0.6996 | Train Loss: 0.9076, Test Loss: 0.9349
# No improvement: 1/7
# Epoch 37/50 | Time: 48.03s | Train Acc: 0.7007, Test Acc: 0.7144 | Train Loss: 0.8934, Test Loss: 0.8959
# ---> New best model saved! Loss: 0.8959
# Epoch 38/50 | Time: 47.96s | Train Acc: 0.7082, Test Acc: 0.7197 | Train Loss: 0.8759, Test Loss: 0.8772
# ---> New best model saved! Loss: 0.8772
# Epoch 39/50 | Time: 48.03s | Train Acc: 0.7089, Test Acc: 0.7254 | Train Loss: 0.8651, Test Loss: 0.8640
# ---> New best model saved! Loss: 0.8640
# Epoch 40/50 | Time: 48.55s | Train Acc: 0.7142, Test Acc: 0.7243 | Train Loss: 0.8568, Test Loss: 0.8672
# No improvement: 1/7
# Epoch 41/50 | Time: 48.22s | Train Acc: 0.7156, Test Acc: 0.7213 | Train Loss: 0.8337, Test Loss: 0.8838
# No improvement: 2/7
# Epoch 42/50 | Time: 47.98s | Train Acc: 0.7207, Test Acc: 0.7292 | Train Loss: 0.8402, Test Loss: 0.8616
# ---> New best model saved! Loss: 0.8616
# Epoch 43/50 | Time: 48.69s | Train Acc: 0.7268, Test Acc: 0.7297 | Train Loss: 0.8207, Test Loss: 0.8579
# ---> New best model saved! Loss: 0.8579
# Epoch 44/50 | Time: 48.74s | Train Acc: 0.7267, Test Acc: 0.7302 | Train Loss: 0.8131, Test Loss: 0.8637
# No improvement: 1/7
# Epoch 45/50 | Time: 48.81s | Train Acc: 0.7341, Test Acc: 0.7302 | Train Loss: 0.7974, Test Loss: 0.8603
# No improvement: 2/7
# Epoch 46/50 | Time: 48.96s | Train Acc: 0.7351, Test Acc: 0.7317 | Train Loss: 0.8008, Test Loss: 0.8559
# ---> New best model saved! Loss: 0.8559
# Epoch 47/50 | Time: 49.19s | Train Acc: 0.7351, Test Acc: 0.7325 | Train Loss: 0.7930, Test Loss: 0.8572
# No improvement: 1/7
# Epoch 48/50 | Time: 49.00s | Train Acc: 0.7368, Test Acc: 0.7322 | Train Loss: 0.7865, Test Loss: 0.8578
# No improvement: 2/7
# Epoch 49/50 | Time: 48.12s | Train Acc: 0.7359, Test Acc: 0.7322 | Train Loss: 0.7819, Test Loss: 0.8602
# No improvement: 3/7
# Epoch 50/50 | Time: 48.20s | Train Acc: 0.7365, Test Acc: 0.7325 | Train Loss: 0.7968, Test Loss: 0.8590
# No improvement: 4/7
#
# ==============================
# Training Complete!
# Total Time: 2402.81s (40.05 min)
# Average Time per Epoch: 48.06s
# Best Test Accuracy: 0.7325
# ==============================
#
# 🔥 FINAL p VALUES:
#
# === p VALUES (per head) ===
# transformer.0.attn: [0.6337449  0.51948494 0.6486127  0.6051199  0.59988207 0.65154463]
# transformer.1.attn: [0.5253315  0.62769556 0.44524655 0.44426396 0.46549466 0.567558  ]
# transformer.2.attn: [0.56143415 0.6272554  0.5657906  0.57891876 0.7594085  0.53611124]
# transformer.3.attn: [0.62561584 0.5864232  0.73327935 0.63023645 0.6470673  0.6368831 ]
# transformer.4.attn: [0.5509512  0.68298924 0.4553266  0.58162737 0.5264618  0.4934644 ]
# transformer.5.attn: [0.50249124 0.3941287  0.4664879  0.46947473 0.38159546 0.5855918 ]
# transformer.6.attn: [0.40191564 0.57609385 0.590273   0.5819152  0.46838343 0.5027428 ]

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as transforms
from vitpol import ViT
import time
import torch.nn.functional as F

# def print_p_values(model):
#     print("\n=== p VALUES (per head) ===")
#     for name, module in model.named_modules():
#         if hasattr(module, "p_raw"):
#             p = 1 + F.softplus(module.p_raw)
#             print(f"{name}: {p.detach().cpu().numpy()}")


def print_p_values(model):
    print("\n=== p VALUES (per head) ===")
    for name, module in model.named_modules():
        if hasattr(module, "p_raw"):
            p = module.p_raw  # ← вот это важно
            print(f"{name}: {p.detach().cpu().numpy()}")
            
def main():

    model = ViT(
        img_size=224,
        patch_size=16,
        num_classes=10,
        in_channels=3,
        dim=384,
        depth=7,
        heads=6
    )

    print(model)

    batch_size = 32

    # Нормализация ImageNet
    normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

    # Аугментации для train 
    transform_train = transforms.Compose([
        transforms.RandomResizedCrop(224, scale=(0.8, 1.0)),  # ← ЗАПЯТАЯ!
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandAugment(num_ops=2, magnitude=9),
        transforms.ToTensor(),
        normalize
    ])

    # Для test/val
    transform_test = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        normalize
    ])

    train_dataset = torchvision.datasets.Imagenette(
        root='../data',
        split='train',
        size='320px',
        download=False,
        transform=transform_train
    )

    test_dataset = torchvision.datasets.Imagenette(
        root='../data',
        split='val',
        size='320px',
        download=False,
        transform=transform_test
    )

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4, pin_memory=True)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = model.to(device)
    optimizer = optim.AdamW(model.parameters(), lr=3e-4, weight_decay=0.05)
    criterion = nn.CrossEntropyLoss()
    scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=50)

    def train_epoch(model, loader, optimizer, criterion, device):
        model.train()
        total_loss, correct, total = 0, 0, 0
        for imgs, labels in loader:
            imgs, labels = imgs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(imgs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            total_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()
        return total_loss / len(loader), correct / total

    def test_epoch(model, loader, criterion, device):
        model.eval()
        total_loss, correct, total = 0, 0, 0
        with torch.no_grad():
            for imgs, labels in loader:
                imgs, labels = imgs.to(device), labels.to(device)
                outputs = model(imgs)
                loss = criterion(outputs, labels)
                
                total_loss += loss.item()
                _, predicted = outputs.max(1)
                total += labels.size(0)
                correct += predicted.eq(labels).sum().item()
        return total_loss / len(loader), correct / total

    # Настройки цикла
    epochs = 50
    test_accs = []
    epoch_times = []  # Список для хранения времени каждой эпохи
    best_test_loss = float('inf')

    # === EARLY STOPPING ===
    patience = 7
    epochs_no_improve = 0

    log_file = open("training_log.txt", "w", encoding="utf-8")

    print(f"Starting training on {device}...")

    for epoch in range(epochs):
        start_time = time.time()  # Засекаем время начала эпохи
        
        train_loss, train_acc = train_epoch(model, train_loader, optimizer, criterion, device)
        test_loss, test_acc = test_epoch(model, test_loader, criterion, device)
        scheduler.step()
        
        end_time = time.time()  # Засекаем время окончания
        epoch_duration = end_time - start_time
        epoch_times.append(epoch_duration)
        
        test_accs.append(test_acc)

        # Подготовка строки лога
        log_str = (f"Epoch {epoch + 1}/{epochs} | "
                   f"Time: {epoch_duration:.2f}s | "
                   f"Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f} | "
                   f"Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}\n")
        
        print(log_str, end="")
        log_file.write(log_str)
        log_file.flush()

        if test_loss < best_test_loss:
            best_test_loss = test_loss
            epochs_no_improve = 0
            torch.save(model.state_dict(), 'best_vit_model.pth')
            print(f"---> New best model saved! Loss: {test_loss:.4f}")
        else:
            epochs_no_improve += 1
            print(f"No improvement: {epochs_no_improve}/{patience}")

        # === EARLY STOPPING ===
        if epochs_no_improve >= patience:
            print(f"\n⛔ Early stopping at epoch {epoch+1}")
            break

        # if (epoch + 1) % 10 == 0:
            # torch.save(model.state_dict(), f'vit_epoch_{epoch+1}.pth')

    # Итоговая статистика
    avg_time = sum(epoch_times) / len(epoch_times)
    total_time = sum(epoch_times)
    
    summary_str = (f"\n{'='*30}\n"
                   f"Training Complete!\n"
                   f"Total Time: {total_time:.2f}s ({total_time/60:.2f} min)\n"
                   f"Average Time per Epoch: {avg_time:.2f}s\n"
                   f"Best Test Accuracy: {max(test_accs):.4f}\n"
                   f"{'='*30}")
    
    print(summary_str)
    log_file.write(summary_str + "\n")
    log_file.close()
    
    print("\n🔥 FINAL p VALUES:")
    print_p_values(model)

if __name__ == "__main__":
    main()
